# %%
# %matplotlib inline
import scrublet as scr
import scipy.io
import matplotlib.pyplot as plt
import numpy as np
import os
import pandas as pd
plt.rcParams['font.family'] = 'sans-serif'
plt.rcParams['font.sans-serif'] = 'Arial'
plt.rc('font', size=14)
plt.rcParams['pdf.fonttype'] = 42

# %%
input_dir = '/project/fsepru/PBMC5/Filtered/A/'
A_counts_matrix = scipy.io.mmread(input_dir + 'matrix.mtx').T.tocsc()
A_genes = np.array(scr.load_genes(input_dir + 'features.tsv', delimiter='\t', column=1))
print('Counts matrix shape: {} rows, {} columns'.format(A_counts_matrix.shape[0], A_counts_matrix.shape[1]))
print('Number of genes in gene list: {}'.format(len(A_genes)))
# Out:
# Counts matrix shape: 3141 rows, 16364 columns
# Number of genes in gene list: 16364

# %%
A_scrub = scr.Scrublet(A_counts_matrix, expected_doublet_rate=0.07)
A_doublet_scores, A_predicted_doublets = A_scrub.scrub_doublets(min_counts=2, min_cells=3, min_gene_variability_pctl=85, n_prin_comps=30)
A_scrub.call_doublets(threshold=0.25)
A_scrub.plot_histogram();
# Out:
# Preprocessing...
# Simulating doublets...
# Embedding transcriptomes using PCA...
# Calculating doublet scores...
# findfont: Font family ['sans-serif'] not found. Falling back to DejaVu Sans.
# Automatically set threshold at doublet score = 0.58
# Detected doublet rate = 0.3%
# Estimated detectable doublet fraction = 5.4%
# Overall doublet rate:
# 	Expected   = 7.0%
# 	Estimated  = 5.3%
# Elapsed time: 2.3 seconds
# Detected doublet rate = 3.0%
# Estimated detectable doublet fraction = 39.4%
# Overall doublet rate:
# 	Expected   = 7.0%
# 	Estimated  = 7.5%
# findfont: Font family ['sans-serif'] not found. Falling back to DejaVu Sans.

# %%
A_scrub.set_embedding('UMAP', scr.get_umap(A_scrub.manifold_obs_, 10, min_dist=0.3))
A_scrub.plot_embedding('UMAP', order_points=True);
# Out:
# /home/sathesh.sivasankaran/.conda/envs/scrublet/lib/python3.8/site-packages/scrublet/scrublet.py:549: MatplotlibDeprecationWarning: Using a string of single character colors as a color sequence is deprecated. Use an explicit list instead.
#   pp = ax.scatter(x[o], y[o], s=marker_size, edgecolors='', c = color_dat[o],
# /home/sathesh.sivasankaran/.conda/envs/scrublet/lib/python3.8/site-packages/scrublet/scrublet.py:562: MatplotlibDeprecationWarning: Using a string of single character colors as a color sequence is deprecated. Use an explicit list instead.
#   ax.scatter(x[o], y[o], s=marker_size, edgecolors='', c=called_doubs[o], cmap=custom_cmap([[.7,.7,.7], [0,0,0]]))

# %%
pdA = pd.DataFrame(A_scrub.doublet_scores_obs_)
pd.DataFrame.to_csv(pdA, "A_ScrubScore.csv")

# %%
input_dir = '/project/fsepru/PBMC5/Filtered/B/'
B_counts_matrix = scipy.io.mmread(input_dir + 'matrix.mtx').T.tocsc()
B_genes = np.array(scr.load_genes(input_dir + 'features.tsv', delimiter='\t', column=1))
print('Counts matrix shape: {} rows, {} columns'.format(B_counts_matrix.shape[0], B_counts_matrix.shape[1]))
print('Number of genes in gene list: {}'.format(len(B_genes)))
# Out:
# Counts matrix shape: 2887 rows, 16364 columns
# Number of genes in gene list: 16364

# %%
B_scrub = scr.Scrublet(B_counts_matrix, expected_doublet_rate=0.07)
B_doublet_scores, B_predicted_doublets = B_scrub.scrub_doublets(min_counts=2, min_cells=3, min_gene_variability_pctl=85, n_prin_comps=30)
B_scrub.call_doublets(threshold=0.25)
B_scrub.plot_histogram();
# Out:
# Preprocessing...
# Simulating doublets...
# Embedding transcriptomes using PCA...
# Calculating doublet scores...
# Automatically set threshold at doublet score = 0.33
# Detected doublet rate = 1.6%
# Estimated detectable doublet fraction = 30.9%
# Overall doublet rate:
# 	Expected   = 7.0%
# 	Estimated  = 5.2%
# Elapsed time: 1.7 seconds
# Detected doublet rate = 2.9%
# Estimated detectable doublet fraction = 42.4%
# Overall doublet rate:
# 	Expected   = 7.0%
# 	Estimated  = 6.8%

# %%
B_scrub.set_embedding('UMAP', scr.get_umap(B_scrub.manifold_obs_, 10, min_dist=0.3))
B_scrub.plot_embedding('UMAP', order_points=True);
# Out:
# /home/sathesh.sivasankaran/.conda/envs/scrublet/lib/python3.8/site-packages/scrublet/scrublet.py:549: MatplotlibDeprecationWarning: Using a string of single character colors as a color sequence is deprecated. Use an explicit list instead.
#   pp = ax.scatter(x[o], y[o], s=marker_size, edgecolors='', c = color_dat[o],
# /home/sathesh.sivasankaran/.conda/envs/scrublet/lib/python3.8/site-packages/scrublet/scrublet.py:562: MatplotlibDeprecationWarning: Using a string of single character colors as a color sequence is deprecated. Use an explicit list instead.
#   ax.scatter(x[o], y[o], s=marker_size, edgecolors='', c=called_doubs[o], cmap=custom_cmap([[.7,.7,.7], [0,0,0]]))

# %%
pdB = pd.DataFrame(B_scrub.doublet_scores_obs_)
pd.DataFrame.to_csv(pdB, "B_ScrubScore.csv")

# %%
input_dir = '/project/fsepru/PBMC5/Filtered/C/'
C_counts_matrix = scipy.io.mmread(input_dir + 'matrix.mtx').T.tocsc()
C_genes = np.array(scr.load_genes(input_dir + 'features.tsv', delimiter='\t', column=1))
print('Counts matrix shape: {} rows, {} columns'.format(C_counts_matrix.shape[0], C_counts_matrix.shape[1]))
print('Number of genes in gene list: {}'.format(len(C_genes)))
# Out:
# Counts matrix shape: 3192 rows, 16364 columns
# Number of genes in gene list: 16364

# %%
C_scrub = scr.Scrublet(C_counts_matrix, expected_doublet_rate=0.07)
C_doublet_scores, C_predicted_doublets = C_scrub.scrub_doublets(min_counts=2, min_cells=3, min_gene_variability_pctl=85, n_prin_comps=30)
C_scrub.call_doublets(threshold=0.25)
C_scrub.plot_histogram();
# Out:
# Preprocessing...
# Simulating doublets...
# Embedding transcriptomes using PCA...
# Calculating doublet scores...
# Automatically set threshold at doublet score = 0.57
# Detected doublet rate = 0.5%
# Estimated detectable doublet fraction = 9.5%
# Overall doublet rate:
# 	Expected   = 7.0%
# 	Estimated  = 5.0%
# Elapsed time: 2.5 seconds
# Detected doublet rate = 3.0%
# Estimated detectable doublet fraction = 42.5%
# Overall doublet rate:
# 	Expected   = 7.0%
# 	Estimated  = 7.1%

# %%
C_scrub.set_embedding('UMAP', scr.get_umap(C_scrub.manifold_obs_, 10, min_dist=0.3))
C_scrub.plot_embedding('UMAP', order_points=True);
# Out:
# /home/sathesh.sivasankaran/.conda/envs/scrublet/lib/python3.8/site-packages/scrublet/scrublet.py:549: MatplotlibDeprecationWarning: Using a string of single character colors as a color sequence is deprecated. Use an explicit list instead.
#   pp = ax.scatter(x[o], y[o], s=marker_size, edgecolors='', c = color_dat[o],
# /home/sathesh.sivasankaran/.conda/envs/scrublet/lib/python3.8/site-packages/scrublet/scrublet.py:562: MatplotlibDeprecationWarning: Using a string of single character colors as a color sequence is deprecated. Use an explicit list instead.
#   ax.scatter(x[o], y[o], s=marker_size, edgecolors='', c=called_doubs[o], cmap=custom_cmap([[.7,.7,.7], [0,0,0]]))

# %%
pdC = pd.DataFrame(C_scrub.doublet_scores_obs_)
pd.DataFrame.to_csv(pdC, "C_ScrubScore.csv")

# %%
input_dir = '/project/fsepru/PBMC5/Filtered/CT21NOV/'
CT21NOV_counts_matrix = scipy.io.mmread(input_dir + 'matrix.mtx').T.tocsc()
CT21NOV_genes = np.array(scr.load_genes(input_dir + 'features.tsv', delimiter='\t', column=1))
print('Counts matrix shape: {} rows, {} columns'.format(CT21NOV_counts_matrix.shape[0], CT21NOV_counts_matrix.shape[1]))
print('Number of genes in gene list: {}'.format(len(CT21NOV_genes)))
# Out:
# Counts matrix shape: 3140 rows, 16364 columns
# Number of genes in gene list: 16364

# %%
CT21NOV_scrub = scr.Scrublet(CT21NOV_counts_matrix, expected_doublet_rate=0.07)
CT21NOV_doublet_scores, CT21NOV_predicted_doublets = CT21NOV_scrub.scrub_doublets(min_counts=2, min_cells=3, min_gene_variability_pctl=85, n_prin_comps=30)
CT21NOV_scrub.call_doublets(threshold=0.25)
CT21NOV_scrub.plot_histogram();
# Out:
# Preprocessing...
# Simulating doublets...
# Embedding transcriptomes using PCA...
# Calculating doublet scores...
# Automatically set threshold at doublet score = 0.57
# Detected doublet rate = 0.2%
# Estimated detectable doublet fraction = 5.3%
# Overall doublet rate:
# 	Expected   = 7.0%
# 	Estimated  = 4.2%
# Elapsed time: 2.4 seconds
# Detected doublet rate = 3.1%
# Estimated detectable doublet fraction = 36.6%
# Overall doublet rate:
# 	Expected   = 7.0%
# 	Estimated  = 8.5%

# %%
CT21NOV_scrub.set_embedding('UMAP', scr.get_umap(CT21NOV_scrub.manifold_obs_, 10, min_dist=0.3))
CT21NOV_scrub.plot_embedding('UMAP', order_points=True);
# Out:
# /home/sathesh.sivasankaran/.conda/envs/scrublet/lib/python3.8/site-packages/scrublet/scrublet.py:549: MatplotlibDeprecationWarning: Using a string of single character colors as a color sequence is deprecated. Use an explicit list instead.
#   pp = ax.scatter(x[o], y[o], s=marker_size, edgecolors='', c = color_dat[o],
# /home/sathesh.sivasankaran/.conda/envs/scrublet/lib/python3.8/site-packages/scrublet/scrublet.py:562: MatplotlibDeprecationWarning: Using a string of single character colors as a color sequence is deprecated. Use an explicit list instead.
#   ax.scatter(x[o], y[o], s=marker_size, edgecolors='', c=called_doubs[o], cmap=custom_cmap([[.7,.7,.7], [0,0,0]]))

# %%
pdCT21NOV = pd.DataFrame(CT21NOV_scrub.doublet_scores_obs_)
pd.DataFrame.to_csv(pdCT21NOV, "CT21NOV_ScrubScore.csv")

# %%
input_dir = '/project/fsepru/PBMC5/Filtered/CT230OCT/'
CT230OCT_counts_matrix = scipy.io.mmread(input_dir + 'matrix.mtx').T.tocsc()
CT230OCT_genes = np.array(scr.load_genes(input_dir + 'features.tsv', delimiter='\t', column=1))
print('Counts matrix shape: {} rows, {} columns'.format(CT230OCT_counts_matrix.shape[0], CT230OCT_counts_matrix.shape[1]))
print('Number of genes in gene list: {}'.format(len(CT230OCT_genes)))
# Out:
# Counts matrix shape: 3912 rows, 16364 columns
# Number of genes in gene list: 16364

# %%
CT230OCT_scrub = scr.Scrublet(CT230OCT_counts_matrix, expected_doublet_rate=0.07)
CT230OCT_doublet_scores, CT230OCT_predicted_doublets = CT230OCT_scrub.scrub_doublets(min_counts=2, min_cells=3, min_gene_variability_pctl=85, n_prin_comps=30)
CT230OCT_scrub.call_doublets(threshold=0.25)
CT230OCT_scrub.plot_histogram();
# Out:
# Preprocessing...
# Simulating doublets...
# Embedding transcriptomes using PCA...
# Calculating doublet scores...
# Automatically set threshold at doublet score = 0.59
# Detected doublet rate = 0.3%
# Estimated detectable doublet fraction = 7.6%
# Overall doublet rate:
# 	Expected   = 7.0%
# 	Estimated  = 4.4%
# Elapsed time: 2.8 seconds
# Detected doublet rate = 2.3%
# Estimated detectable doublet fraction = 43.0%
# Overall doublet rate:
# 	Expected   = 7.0%
# 	Estimated  = 5.4%

# %%
CT230OCT_scrub.set_embedding('UMAP', scr.get_umap(CT230OCT_scrub.manifold_obs_, 10, min_dist=0.3))
CT230OCT_scrub.plot_embedding('UMAP', order_points=True);
# Out:
# /home/sathesh.sivasankaran/.conda/envs/scrublet/lib/python3.8/site-packages/scrublet/scrublet.py:549: MatplotlibDeprecationWarning: Using a string of single character colors as a color sequence is deprecated. Use an explicit list instead.
#   pp = ax.scatter(x[o], y[o], s=marker_size, edgecolors='', c = color_dat[o],
# /home/sathesh.sivasankaran/.conda/envs/scrublet/lib/python3.8/site-packages/scrublet/scrublet.py:562: MatplotlibDeprecationWarning: Using a string of single character colors as a color sequence is deprecated. Use an explicit list instead.
#   ax.scatter(x[o], y[o], s=marker_size, edgecolors='', c=called_doubs[o], cmap=custom_cmap([[.7,.7,.7], [0,0,0]]))

# %%
pdCT230OCT = pd.DataFrame(CT230OCT_scrub.doublet_scores_obs_)
pd.DataFrame.to_csv(pdCT230OCT, "CT230OCT_ScrubScore.csv")

# %%
input_dir = '/project/fsepru/PBMC5/Filtered/PBMC1/'
PBMC1_counts_matrix = scipy.io.mmread(input_dir + 'matrix.mtx').T.tocsc()
PBMC1_genes = np.array(scr.load_genes(input_dir + 'features.tsv', delimiter='\t', column=1))
print('Counts matrix shape: {} rows, {} columns'.format(PBMC1_counts_matrix.shape[0], PBMC1_counts_matrix.shape[1]))
print('Number of genes in gene list: {}'.format(len(PBMC1_genes)))
# Out:
# Counts matrix shape: 6679 rows, 16364 columns
# Number of genes in gene list: 16364

# %%
PBMC1_scrub = scr.Scrublet(PBMC1_counts_matrix, expected_doublet_rate=0.07)
PBMC1_doublet_scores, PBMC1_predicted_doublets = PBMC1_scrub.scrub_doublets(min_counts=2, min_cells=3, min_gene_variability_pctl=85, n_prin_comps=30)
PBMC1_scrub.call_doublets(threshold=0.25)
PBMC1_scrub.plot_histogram();
# Out:
# Preprocessing...
# Simulating doublets...
# Embedding transcriptomes using PCA...
# Calculating doublet scores...
# Automatically set threshold at doublet score = 0.29
# Detected doublet rate = 2.6%
# Estimated detectable doublet fraction = 43.8%
# Overall doublet rate:
# 	Expected   = 7.0%
# 	Estimated  = 5.9%
# Elapsed time: 5.2 seconds
# Detected doublet rate = 3.0%
# Estimated detectable doublet fraction = 47.4%
# Overall doublet rate:
# 	Expected   = 7.0%
# 	Estimated  = 6.3%

# %%
PBMC1_scrub.set_embedding('UMAP', scr.get_umap(PBMC1_scrub.manifold_obs_, 10, min_dist=0.3))
PBMC1_scrub.plot_embedding('UMAP', order_points=True);
# Out:
# /home/sathesh.sivasankaran/.conda/envs/scrublet/lib/python3.8/site-packages/scrublet/scrublet.py:549: MatplotlibDeprecationWarning: Using a string of single character colors as a color sequence is deprecated. Use an explicit list instead.
#   pp = ax.scatter(x[o], y[o], s=marker_size, edgecolors='', c = color_dat[o],
# /home/sathesh.sivasankaran/.conda/envs/scrublet/lib/python3.8/site-packages/scrublet/scrublet.py:562: MatplotlibDeprecationWarning: Using a string of single character colors as a color sequence is deprecated. Use an explicit list instead.
#   ax.scatter(x[o], y[o], s=marker_size, edgecolors='', c=called_doubs[o], cmap=custom_cmap([[.7,.7,.7], [0,0,0]]))

# %%
pdPBMC1 = pd.DataFrame(PBMC1_scrub.doublet_scores_obs_)
pd.DataFrame.to_csv(pdPBMC1, "PBMC1_ScrubScore.csv")

# %%
input_dir = '/project/fsepru/PBMC5/Filtered/PBMC2/'
PBMC2_counts_matrix = scipy.io.mmread(input_dir + 'matrix.mtx').T.tocsc()
PBMC2_genes = np.array(scr.load_genes(input_dir + 'features.tsv', delimiter='\t', column=1))
print('Counts matrix shape: {} rows, {} columns'.format(PBMC2_counts_matrix.shape[0], PBMC2_counts_matrix.shape[1]))
print('Number of genes in gene list: {}'.format(len(PBMC2_genes)))
# Out:
# Counts matrix shape: 6711 rows, 16364 columns
# Number of genes in gene list: 16364

# %%
PBMC2_scrub = scr.Scrublet(PBMC2_counts_matrix, expected_doublet_rate=0.07)
PBMC2_doublet_scores, PBMC2_predicted_doublets = PBMC2_scrub.scrub_doublets(min_counts=2, min_cells=3, min_gene_variability_pctl=85, n_prin_comps=30)
PBMC2_scrub.call_doublets(threshold=0.25)
PBMC2_scrub.plot_histogram();
# Out:
# Preprocessing...
# Simulating doublets...
# Embedding transcriptomes using PCA...
# Calculating doublet scores...
# Automatically set threshold at doublet score = 0.32
# Detected doublet rate = 2.3%
# Estimated detectable doublet fraction = 49.8%
# Overall doublet rate:
# 	Expected   = 7.0%
# 	Estimated  = 4.5%
# Elapsed time: 6.0 seconds
# Detected doublet rate = 2.9%
# Estimated detectable doublet fraction = 55.8%
# Overall doublet rate:
# 	Expected   = 7.0%
# 	Estimated  = 5.2%

# %%
PBMC2_scrub.set_embedding('UMAP', scr.get_umap(PBMC2_scrub.manifold_obs_, 10, min_dist=0.3))
PBMC2_scrub.plot_embedding('UMAP', order_points=True);
# Out:
# /home/sathesh.sivasankaran/.conda/envs/scrublet/lib/python3.8/site-packages/scrublet/scrublet.py:549: MatplotlibDeprecationWarning: Using a string of single character colors as a color sequence is deprecated. Use an explicit list instead.
#   pp = ax.scatter(x[o], y[o], s=marker_size, edgecolors='', c = color_dat[o],
# /home/sathesh.sivasankaran/.conda/envs/scrublet/lib/python3.8/site-packages/scrublet/scrublet.py:562: MatplotlibDeprecationWarning: Using a string of single character colors as a color sequence is deprecated. Use an explicit list instead.
#   ax.scatter(x[o], y[o], s=marker_size, edgecolors='', c=called_doubs[o], cmap=custom_cmap([[.7,.7,.7], [0,0,0]]))

# %%
pdPBMC2 = pd.DataFrame(PBMC2_scrub.doublet_scores_obs_)
pd.DataFrame.to_csv(pdPBMC2, "PBMC2_ScrubScore.csv")
