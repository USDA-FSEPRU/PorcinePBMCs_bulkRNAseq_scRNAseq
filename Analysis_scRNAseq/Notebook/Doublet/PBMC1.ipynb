# %%
# %matplotlib inline
import scrublet as scr
import scipy.io
import matplotlib.pyplot as plt
import numpy as np
import os
import pandas as pd
plt.rcParams['font.family'] = 'sans-serif'
plt.rcParams['font.sans-serif'] = 'Arial'
plt.rc('font', size=14)
plt.rcParams['pdf.fonttype'] = 42

# %%
input_dir = '/project/fsepru/PBMC5/Filtered/PBMC1/'
PBMC1_counts_matrix = scipy.io.mmread(input_dir + 'matrix.mtx').T.tocsc()
PBMC1_genes = np.array(scr.load_genes(input_dir + 'features.tsv', delimiter='\t', column=1))
print('Counts matrix shape: {} rows, {} columns'.format(PBMC1_counts_matrix.shape[0], PBMC1_counts_matrix.shape[1]))
print('Number of genes in gene list: {}'.format(len(PBMC1_genes)))
# Out:
# Counts matrix shape: 6679 rows, 16364 columns
# Number of genes in gene list: 16364

# %%
PBMC1_scrub = scr.Scrublet(PBMC1_counts_matrix, expected_doublet_rate=0.06)
PBMC1_doublet_scores, PBMC1_predicted_doublets = PBMC1_scrub.scrub_doublets(min_counts=2, min_cells=3, min_gene_variability_pctl=85, n_prin_comps=30)
PBMC1_scrub.call_doublets(threshold=0.0)
PBMC1_scrub.plot_histogram();
# Out:
# Preprocessing...
# Simulating doublets...
# Embedding transcriptomes using PCA...
# Calculating doublet scores...
# findfont: Font family ['sans-serif'] not found. Falling back to DejaVu Sans.
# Automatically set threshold at doublet score = 0.26
# Detected doublet rate = 2.6%
# Estimated detectable doublet fraction = 43.8%
# Overall doublet rate:
# 	Expected   = 6.0%
# 	Estimated  = 5.9%
# Elapsed time: 5.9 seconds
# Detected doublet rate = 100.0%
# Estimated detectable doublet fraction = 100.0%
# Overall doublet rate:
# 	Expected   = 6.0%
# 	Estimated  = 100.0%
# findfont: Font family ['sans-serif'] not found. Falling back to DejaVu Sans.

# %%
PBMC1_scrub = scr.Scrublet(PBMC1_counts_matrix, expected_doublet_rate=0.065)
PBMC1_doublet_scores, PBMC1_predicted_doublets = PBMC1_scrub.scrub_doublets(min_counts=2, min_cells=3, min_gene_variability_pctl=85, n_prin_comps=30)
PBMC1_scrub.call_doublets(threshold=0.0)
PBMC1_scrub.plot_histogram();
# Out:
# Preprocessing...
# Simulating doublets...
# Embedding transcriptomes using PCA...
# Calculating doublet scores...
# Automatically set threshold at doublet score = 0.28
# Detected doublet rate = 2.6%
# Estimated detectable doublet fraction = 43.8%
# Overall doublet rate:
# 	Expected   = 6.5%
# 	Estimated  = 5.9%
# Elapsed time: 5.4 seconds
# Detected doublet rate = 100.0%
# Estimated detectable doublet fraction = 100.0%
# Overall doublet rate:
# 	Expected   = 6.5%
# 	Estimated  = 100.0%

# %%
PBMC1_scrub = scr.Scrublet(PBMC1_counts_matrix, expected_doublet_rate=0.07)
PBMC1_doublet_scores, PBMC1_predicted_doublets = PBMC1_scrub.scrub_doublets(min_counts=2, min_cells=3, min_gene_variability_pctl=85, n_prin_comps=30)
PBMC1_scrub.call_doublets(threshold=0.0)
PBMC1_scrub.plot_histogram();
# Out:
# Preprocessing...
# Simulating doublets...
# Embedding transcriptomes using PCA...
# Calculating doublet scores...
# Automatically set threshold at doublet score = 0.29
# Detected doublet rate = 2.6%
# Estimated detectable doublet fraction = 43.8%
# Overall doublet rate:
# 	Expected   = 7.0%
# 	Estimated  = 5.9%
# Elapsed time: 5.4 seconds
# Detected doublet rate = 100.0%
# Estimated detectable doublet fraction = 100.0%
# Overall doublet rate:
# 	Expected   = 7.0%
# 	Estimated  = 100.0%

# %%
PBMC1_scrub = scr.Scrublet(PBMC1_counts_matrix, expected_doublet_rate=0.075)
PBMC1_doublet_scores, PBMC1_predicted_doublets = PBMC1_scrub.scrub_doublets(min_counts=2, min_cells=3, min_gene_variability_pctl=85, n_prin_comps=30)
PBMC1_scrub.call_doublets(threshold=0.0)
PBMC1_scrub.plot_histogram();
# Out:
# Preprocessing...
# Simulating doublets...
# Embedding transcriptomes using PCA...
# Calculating doublet scores...
# Automatically set threshold at doublet score = 0.31
# Detected doublet rate = 2.6%
# Estimated detectable doublet fraction = 43.8%
# Overall doublet rate:
# 	Expected   = 7.5%
# 	Estimated  = 5.9%
# Elapsed time: 5.7 seconds
# Detected doublet rate = 100.0%
# Estimated detectable doublet fraction = 100.0%
# Overall doublet rate:
# 	Expected   = 7.5%
# 	Estimated  = 100.0%

# %%
PBMC1_scrub = scr.Scrublet(PBMC1_counts_matrix, expected_doublet_rate=0.08)
PBMC1_doublet_scores, PBMC1_predicted_doublets = PBMC1_scrub.scrub_doublets(min_counts=2, min_cells=3, min_gene_variability_pctl=85, n_prin_comps=30)
PBMC1_scrub.call_doublets(threshold=0.0)
PBMC1_scrub.plot_histogram();
# Out:
# Preprocessing...
# Simulating doublets...
# Embedding transcriptomes using PCA...
# Calculating doublet scores...
# Automatically set threshold at doublet score = 0.32
# Detected doublet rate = 2.6%
# Estimated detectable doublet fraction = 43.8%
# Overall doublet rate:
# 	Expected   = 8.0%
# 	Estimated  = 5.9%
# Elapsed time: 6.0 seconds
# Detected doublet rate = 100.0%
# Estimated detectable doublet fraction = 100.0%
# Overall doublet rate:
# 	Expected   = 8.0%
# 	Estimated  = 100.0%
